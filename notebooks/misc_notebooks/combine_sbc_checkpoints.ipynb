# %% [markdown]
# This is a helper notebook that combines batched SBC run files into a single file.

# %%
import torch
import numpy as np
import pickle
import yaml
import os

# %%
results_path = "/Users/Lieve/Documents/Masters Project/SBC-SBI/results/real_examples/gipps_7d/npe_c/"

# %%
paths = []
ranks = []
configs = []
for i in range(4):
    rks = np.load(results_path + f"sequential_sbc2_leader_trajectory0_checkpoint{i}.npz")
    with open(results_path + f"sequential_sbc2_leader_trajectory0_checkpoint{i}.yaml", "r") as f:
        cfg = yaml.safe_load(f)
    ranks.append(rks)
    configs.append(cfg)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 5
#       3 configs = []
#       4 for i in range(4):
# ----> 5     rks = np.load(results_path + f"sequential_sbc2_leader_trajectory0_checkpoint{i}.npz")
#       6     with open(results_path + f"sequential_sbc2_leader_trajectory0_checkpoint{i}.yaml", "r") as f:
#       7         cfg = yaml.safe_load(f)
#
# File ~/Documents/Masters Project/sbi_venv/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Lieve/Documents/Masters Project/SBC-SBI/results/real_examples/gipps_7d/npe_c/sequential_sbc2_leader_trajectory0_checkpoint0.npz'

# %%
def view_checkpointed_sbc_ranks(sequential_sbc_ID, results_path):
    # Iterate through all checkpoints
    checkpoint_ID = 0
    print("THE FOLLOWING FILES EXIST:")
    while os.path.exists(results_path + f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}" + ".npy"):
        print(f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}" + ".npy")
        if os.path.exists(results_path + f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}" + ".yaml"):
            print(f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}" + ".yaml")
        if os.path.exists(results_path + f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}_simulations" + ".npz"):
            print(f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}_simulations" + ".npz")
        checkpoint_ID += 1

def retrieve_and_combine_checkpointed_sbc_ranks(sequential_sbc_ID, results_path):
    ranks = []
    config = {}
    sbc_round_ID = 0
    simulations = {}
    N_iter = 0
    sbc_time = 0

    # Iterate through all checkpoints
    checkpoint_ID = 0
    while os.path.exists(results_path + f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}" + ".npy"):
        sequential_ranks_name = f"sequential_sbc_ranks{sequential_sbc_ID}_checkpoint{checkpoint_ID}"
        path_to_sequential_ranks = results_path + sequential_ranks_name + ".npy"
        path_to_sequential_ranks_config = results_path + sequential_ranks_name + ".yaml"
        path_to_sequential_ranks_simulations = results_path + sequential_ranks_name + "_simulations" + ".npz"
        
        # Load sbc ranks
        sequential_ranks = np.load(path_to_sequential_ranks)

        # Load config
        with open(path_to_sequential_ranks_config, "r") as f:
            sequential_ranks_config = yaml.safe_load(f)

        # Load samples
        sequential_ranks_simulations = np.load(path_to_sequential_ranks_simulations)

        # Append checkpoint's ranks to collection of ranks
        ranks += list(sequential_ranks)

        # Append checkpoint's samples to collection of samples
        i = 0
        while f"posterior_samples_round_{i}" in sequential_ranks_simulations:
            simulations[f"posterior_samples_round_{sbc_round_ID}"] = sequential_ranks_simulations[f"posterior_samples_round_{i}"]
            simulations[f"prior_sample_round_{sbc_round_ID}"] = sequential_ranks_simulations[f"prior_sample_round_{i}"]
            simulations[f"data_sample_round_{sbc_round_ID}"] = sequential_ranks_simulations[f"data_sample_round_{i}"]
            i += 1
            sbc_round_ID += 1

        # Increment N_iter and sbc_time
        N_iter += sequential_ranks_config["N_iter"]
        sbc_time += sequential_ranks_config["checkpoint_sbc_time"]

        if checkpoint_ID == 0:
            config["num_sequential_rounds"] = sequential_ranks_config["num_sequential_rounds"]
            config["num_simulations_per_round"] = sequential_ranks_config["num_simulations_per_round"]
            config["sigma"] = sequential_ranks_config["sigma"]
            config["N_samp"] = sequential_ranks_config["N_samp"]

        checkpoint_ID += 1
    config["N_iter"] = N_iter
    config["sbc_time"] = sbc_time
    ranks = np.array(ranks)
    sbc_dict = {"ranks": ranks, "config": config, "simulations": simulations}
    return sbc_dict


def save_combined_checkpointed_sbc_ranks(sequential_sbc_ID, results_path, sbc_dict):
    if os.path.exists(results_path + f"sequential_sbc_ranks{sequential_sbc_ID}.npy"):
        raise AssertionError("A folder with this name already exists. Please delete it if you want to overwrite it.")

    ranks_sequential = sbc_dict["ranks"]
    samples_dict = sbc_dict["simulations"]
    config = sbc_dict["config"]

    sequential_sbc_save_path = results_path + f"sequential_sbc_ranks{sequential_sbc_ID}.npy"
    config_save_path = results_path + f"sequential_sbc_ranks{sequential_sbc_ID}.yaml"
    simulations_save_path = results_path + f"sequential_sbc_ranks{sequential_sbc_ID}_simulations.npz"

    print(f"\n Saving ranks to {sequential_sbc_save_path}:")
    np.save(sequential_sbc_save_path, ranks_sequential)
    print("\n Ranks saved successfully.")

    print(f"\n Saving config file to {config_save_path}:")
    with open(config_save_path, "w") as f:
        yaml.safe_dump(config, f)
    print("\n Config file saved successfully.")

    # Save simulations:
    print(f"\n Saving simulations to {simulations_save_path}:")
    np.savez(simulations_save_path, **samples_dict)
    print("\n Simulations saved successfully.")

# %%
# Define results path

# %%
# Define the sequential_sbc_ID to READ FROM (this should be checkpointed)
sequential_sbc_ID_read = 2

# %%
# Inspect the files
view_checkpointed_sbc_ranks(sequential_sbc_ID_read, results_path)
# Out:
# THE FOLLOWING FILES EXIST:

# %%
sbc_dict = retrieve_and_combine_checkpointed_sbc_ranks(sequential_sbc_ID=sequential_sbc_ID_read,
                                                       results_path=results_path)

# %%
# Inspect ranks to double check they have been combined correctly:
sequential_ranks = sbc_dict["ranks"]
#sequential_ranks

# %%
# Inspect config to double check they have been combined correctly:
sequential_ranks_config = sbc_dict["config"]
#sequential_ranks_config
# Out:
# {'num_sequential_rounds': 4,
#  'num_simulations_per_round': 5000,
#  'sigma': 150.0,
#  'N_samp': 10000,
#  'N_iter': 900,
#  'sbc_time': 249688.01264716126}

# %%
# Inspect simulations to double check they have been combined correctly:
sequential_ranks_simulations = sbc_dict["simulations"]
#sequential_ranks_simulations

# %%
# ONCE HAPPY:
sequential_sbc_ID_write = 1

# Write the combined files to a single file
save_combined_checkpointed_sbc_ranks(sequential_sbc_ID=sequential_sbc_ID_read,
                                     results_path=results_path,
                                     sbc_dict=sbc_dict)
# Out:
#  Saving ranks to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks1.npy:
#
#  Ranks saved.
#
#  Saving config file to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks1.yaml:
#
#  Config file saved successfully.
#
#  Saving simulations to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks1_simulations.npz:
#
#  Simulations saved successfully.

# %%
path_all = "/Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_a/"

# %%
# Load config
with open(path_all + "sequential_sbc_ranks0.yaml", "r") as f:
    config = yaml.safe_load(f)

# %%
config["sbc_times"] = [np.nan for i in range(1000)]

# %%
config
# Out:
# {'N_iter': 1000,
#  'N_samp': 10000,
#  'num_components': 1,
#  'num_sequential_rounds': 4,
#  'num_simulations_per_round': 5000,
#  'sigma': 150.0,
#  'total_sbc_time': 41978.55242218962,
#  'sbc_times': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]}

# %%
# Load sbc ranks
ranks0 = np.load(path_all + "sequential_sbc_ranks0.npy")
ranks1 = np.load(path_all + "sequential_sbc_ranks1.npy")

# Load config
with open(path_all + "sequential_sbc_ranks0.yaml", "r") as f:
    config0 = yaml.safe_load(f)

# Load config
with open(path_all + "sequential_sbc_ranks1.yaml", "r") as f:
    config1 = yaml.safe_load(f) 

# Load samples
samples0 = np.load(path_all + "sequential_sbc_ranks0_simulations.npz")
samples1 = np.load(path_all + "sequential_sbc_ranks1_simulations.npz")

# %%
path_all = "/Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_a/"

samples_old = np.load(path_all + "sequential_sbc_ranks0_simulations.npz")

# %%
dict(samples_old).keys()
# Out:
# dict_keys(['prior_sample_round_0_checkpoint0', 'data_sample_round_0_checkpoint0', 'posterior_samples_round_0_checkpoint0', 'prior_sample_round_1_checkpoint0', 'data_sample_round_1_checkpoint0', 'posterior_samples_round_1_checkpoint0', 'prior_sample_round_2_checkpoint0', 'data_sample_round_2_checkpoint0', 'posterior_samples_round_2_checkpoint0', 'prior_sample_round_3_checkpoint0', 'data_sample_round_3_checkpoint0', 'posterior_samples_round_3_checkpoint0', 'prior_sample_round_4_checkpoint0', 'data_sample_round_4_checkpoint0', 'posterior_samples_round_4_checkpoint0', 'prior_sample_round_5_checkpoint0', 'data_sample_round_5_checkpoint0', 'posterior_samples_round_5_checkpoint0', 'prior_sample_round_6_checkpoint0', 'data_sample_round_6_checkpoint0', 'posterior_samples_round_6_checkpoint0', 'prior_sample_round_7_checkpoint0', 'data_sample_round_7_checkpoint0', 'posterior_samples_round_7_checkpoint0', 'prior_sample_round_8_checkpoint0', 'data_sample_round_8_checkpoint0', 'posterior_samples_round_8_checkpoint0', 'prior_sample_round_9_checkpoint0', 'data_sample_round_9_checkpoint0', 'posterior_samples_round_9_checkpoint0', 'prior_sample_round_10_checkpoint0', 'data_sample_round_10_checkpoint0', 'posterior_samples_round_10_checkpoint0', 'prior_sample_round_11_checkpoint0', 'data_sample_round_11_checkpoint0', 'posterior_samples_round_11_checkpoint0', 'prior_sample_round_12_checkpoint0', 'data_sample_round_12_checkpoint0', 'posterior_samples_round_12_checkpoint0', 'prior_sample_round_13_checkpoint0', 'data_sample_round_13_checkpoint0', 'posterior_samples_round_13_checkpoint0', 'prior_sample_round_14_checkpoint0', 'data_sample_round_14_checkpoint0', 'posterior_samples_round_14_checkpoint0', 'prior_sample_round_15_checkpoint0', 'data_sample_round_15_checkpoint0', 'posterior_samples_round_15_checkpoint0', 'prior_sample_round_16_checkpoint0', 'data_sample_round_16_checkpoint0', 'posterior_samples_round_16_checkpoint0', 'prior_sample_round_17_checkpoint0', 'data_sample_round_17_checkpoint0', 'posterior_samples_round_17_checkpoint0', 'prior_sample_round_18_checkpoint0', 'data_sample_round_18_checkpoint0', 'posterior_samples_round_18_checkpoint0', 'prior_sample_round_19_checkpoint0', 'data_sample_round_19_checkpoint0', 'posterior_samples_round_19_checkpoint0', 'prior_sample_round_20_checkpoint0', 'data_sample_round_20_checkpoint0', 'posterior_samples_round_20_checkpoint0', 'prior_sample_round_21_checkpoint0', 'data_sample_round_21_checkpoint0', 'posterior_samples_round_21_checkpoint0', 'prior_sample_round_22_checkpoint0', 'data_sample_round_22_checkpoint0', 'posterior_samples_round_22_checkpoint0', 'prior_sample_round_23_checkpoint0', 'data_sample_round_23_checkpoint0', 'posterior_samples_round_23_checkpoint0', 'prior_sample_round_24_checkpoint0', 'data_sample_round_24_checkpoint0', 'posterior_samples_round_24_checkpoint0', 'prior_sample_round_25_checkpoint0', 'data_sample_round_25_checkpoint0', 'posterior_samples_round_25_checkpoint0', 'prior_sample_round_26_checkpoint0', 'data_sample_round_26_checkpoint0', 'posterior_samples_round_26_checkpoint0', 'prior_sample_round_27_checkpoint0', 'data_sample_round_27_checkpoint0', 'posterior_samples_round_27_checkpoint0', 'prior_sample_round_28_checkpoint0', 'data_sample_round_28_checkpoint0', 'posterior_samples_round_28_checkpoint0', 'prior_sample_round_29_checkpoint0', 'data_sample_round_29_checkpoint0', 'posterior_samples_round_29_checkpoint0', 'prior_sample_round_30_checkpoint0', 'data_sample_round_30_checkpoint0', 'posterior_samples_round_30_checkpoint0', 'prior_sample_round_31_checkpoint0', 'data_sample_round_31_checkpoint0', 'posterior_samples_round_31_checkpoint0', 'prior_sample_round_32_checkpoint0', 'data_sample_round_32_checkpoint0', 'posterior_samples_round_32_checkpoint0', 'prior_sample_round_33_checkpoint0', 'data_sample_round_33_checkpoint0', 'posterior_samples_round_33_checkpoint0', 'prior_sample_round_34_checkpoint0', 'data_sample_round_34_checkpoint0', 'posterior_samples_round_34_checkpoi ...

# %%
samples = {}

k = 0
for j in range(10):
    for i in range(100):
        samples[f"prior_sample_round_{k}"] = samples_old[f"prior_sample_round_{i}_checkpoint{j}"]
        samples[f"data_sample_round_{k}"] = samples_old[f"data_sample_round_{i}_checkpoint{j}"]
        samples[f"posterior_samples_round_{k}"] = samples_old[f"posterior_samples_round_{i}_checkpoint{j}"]
        k += 1

# %%
samples.keys()
# Out:
# dict_keys(['prior_sample_round_0', 'data_sample_round_0', 'posterior_samples_round_0', 'prior_sample_round_1', 'data_sample_round_1', 'posterior_samples_round_1', 'prior_sample_round_2', 'data_sample_round_2', 'posterior_samples_round_2', 'prior_sample_round_3', 'data_sample_round_3', 'posterior_samples_round_3', 'prior_sample_round_4', 'data_sample_round_4', 'posterior_samples_round_4', 'prior_sample_round_5', 'data_sample_round_5', 'posterior_samples_round_5', 'prior_sample_round_6', 'data_sample_round_6', 'posterior_samples_round_6', 'prior_sample_round_7', 'data_sample_round_7', 'posterior_samples_round_7', 'prior_sample_round_8', 'data_sample_round_8', 'posterior_samples_round_8', 'prior_sample_round_9', 'data_sample_round_9', 'posterior_samples_round_9', 'prior_sample_round_10', 'data_sample_round_10', 'posterior_samples_round_10', 'prior_sample_round_11', 'data_sample_round_11', 'posterior_samples_round_11', 'prior_sample_round_12', 'data_sample_round_12', 'posterior_samples_round_12', 'prior_sample_round_13', 'data_sample_round_13', 'posterior_samples_round_13', 'prior_sample_round_14', 'data_sample_round_14', 'posterior_samples_round_14', 'prior_sample_round_15', 'data_sample_round_15', 'posterior_samples_round_15', 'prior_sample_round_16', 'data_sample_round_16', 'posterior_samples_round_16', 'prior_sample_round_17', 'data_sample_round_17', 'posterior_samples_round_17', 'prior_sample_round_18', 'data_sample_round_18', 'posterior_samples_round_18', 'prior_sample_round_19', 'data_sample_round_19', 'posterior_samples_round_19', 'prior_sample_round_20', 'data_sample_round_20', 'posterior_samples_round_20', 'prior_sample_round_21', 'data_sample_round_21', 'posterior_samples_round_21', 'prior_sample_round_22', 'data_sample_round_22', 'posterior_samples_round_22', 'prior_sample_round_23', 'data_sample_round_23', 'posterior_samples_round_23', 'prior_sample_round_24', 'data_sample_round_24', 'posterior_samples_round_24', 'prior_sample_round_25', 'data_sample_round_25', 'posterior_samples_round_25', 'prior_sample_round_26', 'data_sample_round_26', 'posterior_samples_round_26', 'prior_sample_round_27', 'data_sample_round_27', 'posterior_samples_round_27', 'prior_sample_round_28', 'data_sample_round_28', 'posterior_samples_round_28', 'prior_sample_round_29', 'data_sample_round_29', 'posterior_samples_round_29', 'prior_sample_round_30', 'data_sample_round_30', 'posterior_samples_round_30', 'prior_sample_round_31', 'data_sample_round_31', 'posterior_samples_round_31', 'prior_sample_round_32', 'data_sample_round_32', 'posterior_samples_round_32', 'prior_sample_round_33', 'data_sample_round_33', 'posterior_samples_round_33', 'prior_sample_round_34', 'data_sample_round_34', 'posterior_samples_round_34', 'prior_sample_round_35', 'data_sample_round_35', 'posterior_samples_round_35', 'prior_sample_round_36', 'data_sample_round_36', 'posterior_samples_round_36', 'prior_sample_round_37', 'data_sample_round_37', 'posterior_samples_round_37', 'prior_sample_round_38', 'data_sample_round_38', 'posterior_samples_round_38', 'prior_sample_round_39', 'data_sample_round_39', 'posterior_samples_round_39', 'prior_sample_round_40', 'data_sample_round_40', 'posterior_samples_round_40', 'prior_sample_round_41', 'data_sample_round_41', 'posterior_samples_round_41', 'prior_sample_round_42', 'data_sample_round_42', 'posterior_samples_round_42', 'prior_sample_round_43', 'data_sample_round_43', 'posterior_samples_round_43', 'prior_sample_round_44', 'data_sample_round_44', 'posterior_samples_round_44', 'prior_sample_round_45', 'data_sample_round_45', 'posterior_samples_round_45', 'prior_sample_round_46', 'data_sample_round_46', 'posterior_samples_round_46', 'prior_sample_round_47', 'data_sample_round_47', 'posterior_samples_round_47', 'prior_sample_round_48', 'data_sample_round_48', 'posterior_samples_round_48', 'prior_sample_round_49', 'data_sample_round_49', 'posterior_samples_round_49', 'prior_sample_round_50', 'data_sample_round_50', 'posterior_samples_r ...

# %%
simulations_save_path = path_all + "sequential_sbc_ranks0_simulations.npz"

# Save simulations:
print(f"\n Saving simulations to {simulations_save_path}:")
np.savez(simulations_save_path, **samples)
print("\n Simulations saved successfully.")
# Out:
#  Saving simulations to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_a/sequential_sbc_ranks0_simulations.npz:
#
#  Simulations saved successfully.

# %%
sequential_sbc_save_path = path_all + "sequential_sbc_ranks3.npy"
config_save_path = path_all + "sequential_sbc_ranks3.yaml"
simulations_save_path = path_all + "sequential_sbc_ranks3_simulations.npz"


print(f"\n Saving ranks to {sequential_sbc_save_path}:")
np.save(sequential_sbc_save_path, ranks)
print("\n Ranks saved successfully.")

print(f"\n Saving config file to {config_save_path}:")
with open(config_save_path, "w") as f:
    yaml.safe_dump(config, f)
print("\n Config file saved successfully.")

# Save simulations:
print(f"\n Saving simulations to {simulations_save_path}:")
np.savez(simulations_save_path, **samples)
print("\n Simulations saved successfully.")
# Out:
#  Saving ranks to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks3.npy:
#
#  Ranks saved successfully.
#
#  Saving config file to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks3.yaml:
#
#  Config file saved successfully.
#
#  Saving simulations to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_c/sequential_sbc_ranks3_simulations.npz:
#
#  Simulations saved successfully.

# %%
config_save_path = path_all + "sequential_sbc_ranks0.yaml"
print(f"\n Saving config file to {config_save_path}:")
with open(config_save_path, "w") as f:
    yaml.safe_dump(config, f)
print("\n Config file saved successfully.")
# Out:
#  Saving config file to /Users/Lieve/Documents/Masters Project/SBC-SBI/results/toy_examples/norm_norm_diffuse_1d/npe_a/sequential_sbc_ranks0.yaml:
#
#  Config file saved successfully.

# %%
config
# Out:
# {'N_iter': 1000,
#  'N_samp': 10000,
#  'num_components': 1,
#  'num_sequential_rounds': 4,
#  'num_simulations_per_round': 5000,
#  'sigma': 150.0,
#  'total_sbc_time': 41978.55242218962,
#  'sbc_times': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]}
